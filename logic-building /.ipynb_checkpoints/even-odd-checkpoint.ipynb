# %%
number = int(input("Enter your number: "))

# Checking Even or off 
if number % 2 == 0:
    print(True)
else:
    print(False)
# Out:
# Enter your number:  7
# False

# %%
def main():
    num = int(input("Enter the number: "))
    check = check_oddeven(num)
    print(check)
    
    

def check_oddeven(number):
    if number % 2 == 0:
        return True
    else:
        return False

if __name__ == "__main__":
    main()
# Out:
# Enter the number:  3
# False

# %%
def main():
    num = int(input("Enter the number: "))
    check = check_oddeven(num)
    print(check)

def check_oddeven(number):
    if (number & 1) == 0:
        return True
    else:
        return False

if __name__ == "__main__":
    main()
# Out:
# Enter the number:  5
# False

# %% [markdown]
# #### Note: Bitwise operators are extremely fast and efficient because they operate directly at the binary level, making them significantly faster than arithmetic or logical operations.
